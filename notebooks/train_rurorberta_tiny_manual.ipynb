# %% [markdown]
# ## Обучение облегчённой RuBERT (rubert-tiny2) для классификации тональности
# Скрипт загружает размеченные данные, инициализирует компактную модель `cointegrated/rubert-tiny2` для трёхклассовой классификации и обучает её с использованием градиентного накопления, линейного scheduler’а с warmup и мониторинга метрик (loss, accuracy, macro-F1) на train/val. Лучшая по macro-F1 версия модели и токенизатор сохраняются в `OUTPUT_DIR`, а история обучения экспортируется в CSV-файл для дальнейшего анализа.

# %%
import os
import time
import random
import math
from typing import List, Dict

import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import f1_score, accuracy_score
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    get_linear_schedule_with_warmup,
)

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# ===== Пути =====
TRAIN_CLEAN_PATH = "../data/processed/train_super.csv"
VAL_CLEAN_PATH   = "../data/processed/val_super.csv"

MODEL_ID   = "cointegrated/rubert-tiny2"
OUTPUT_DIR = "../models/rurorberta_tiny_manual"

# ===== Гиперпараметры =====
NUM_LABELS         = 3
MAX_LEN            = 192     
EPOCHS             = 2       
BATCH_SIZE         = 8       
GRAD_ACCUM_STEPS   = 4       
LEARNING_RATE      = 2e-5    
WARMUP_RATIO       = 0.06     
RANDOM_STATE       = 42

MAX_TRAIN_SAMPLES  = None  


def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


class TextDataset(Dataset):
    def __init__(self, texts: List[str], labels: List[int], tokenizer, max_len: int):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx: int) -> Dict[str, torch.Tensor]:
        text = str(self.texts[idx])
        label = int(self.labels[idx])

        enc = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_len,
            return_tensors="pt",
        )

        return {
            "input_ids": enc["input_ids"].squeeze(0),
            "attention_mask": enc["attention_mask"].squeeze(0),
            "labels": torch.tensor(label, dtype=torch.long),
        }


def train_one_epoch(
    model,
    dataloader,
    optimizer,
    scheduler,
    device,
    grad_accum_steps: int = 1,
    epoch_idx: int = 1,
):
    model.train()
    total_loss = 0.0
    all_preds = []
    all_labels = []

    optimizer.zero_grad()

    num_batches = len(dataloader)
    start_time = time.time()

    for step, batch in enumerate(dataloader):
        batch = {k: v.to(device) for k, v in batch.items()}

        outputs = model(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            labels=batch["labels"],
        )

        loss = outputs.loss / grad_accum_steps
        logits = outputs.logits

        loss.backward()
        total_loss += loss.item() * grad_accum_steps  # считаем "настоящий" лосс

        if (step + 1) % grad_accum_steps == 0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()

            if device.type == "mps":
                torch.mps.empty_cache()

        preds = torch.argmax(logits, dim=-1).detach().cpu().numpy()
        labels = batch["labels"].detach().cpu().numpy()
        all_preds.append(preds)
        all_labels.append(labels)

        # прогресс каждые 200 батчей
        if (step + 1) % 200 == 0 or (step + 1) == num_batches:
            elapsed = (time.time() - start_time) / 60
            avg_loss_so_far = total_loss / (step + 1)
            progress = 100.0 * (step + 1) / num_batches
            lr = scheduler.get_last_lr()[0]
            print(
                f"[Train] Epoch {epoch_idx} | "
                f"batch {step+1}/{num_batches} ({progress:.1f}%) | "
                f"avg_loss: {avg_loss_so_far:.4f} | lr: {lr:.6f} | "
                f"elapsed: {elapsed:.1f} мин"
            )

    all_preds = np.concatenate(all_preds)
    all_labels = np.concatenate(all_labels)

    avg_loss = total_loss / len(dataloader)
    acc = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average="macro")

    return avg_loss, acc, f1


def eval_one_epoch(model, dataloader, device, epoch_idx: int = 1):
    model.eval()
    total_loss = 0.0
    all_preds = []
    all_labels = []

    num_batches = len(dataloader)
    start_time = time.time()

    with torch.no_grad():
        for step, batch in enumerate(dataloader):
            batch = {k: v.to(device) for k, v in batch.items()}

            outputs = model(
                input_ids=batch["input_ids"],
                attention_mask=batch["attention_mask"],
                labels=batch["labels"],
            )

            loss = outputs.loss
            logits = outputs.logits

            total_loss += loss.item()

            preds = torch.argmax(logits, dim=-1).detach().cpu().numpy()
            labels = batch["labels"].detach().cpu().numpy()
            all_preds.append(preds)
            all_labels.append(labels)

            if (step + 1) % 200 == 0 or (step + 1) == num_batches:
                elapsed = (time.time() - start_time) / 60
                avg_loss_so_far = total_loss / (step + 1)
                progress = 100.0 * (step + 1) / num_batches
                print(
                    f"[Val] Epoch {epoch_idx} | "
                    f"batch {step+1}/{num_batches} ({progress:.1f}%) | "
                    f"avg_loss: {avg_loss_so_far:.4f} | "
                    f"elapsed: {elapsed:.1f} мин"
                )

    all_preds = np.concatenate(all_preds)
    all_labels = np.concatenate(all_labels)

    avg_loss = total_loss / len(dataloader)
    acc = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average="macro")

    return avg_loss, acc, f1


def main():
    set_seed(RANDOM_STATE)

    assert os.path.exists(TRAIN_CLEAN_PATH), f"Нет файла {TRAIN_CLEAN_PATH}"
    assert os.path.exists(VAL_CLEAN_PATH),   f"Нет файла {VAL_CLEAN_PATH}"

    print("Читаем данные...")
    train_df = pd.read_csv(TRAIN_CLEAN_PATH)
    val_df   = pd.read_csv(VAL_CLEAN_PATH)

    for col in ["text", "label"]:
        if col not in train_df.columns:
            raise ValueError(f"В train_super нет колонки '{col}'")
        if col not in val_df.columns:
            raise ValueError(f"В val_super нет колонки '{col}'")

    if MAX_TRAIN_SAMPLES is not None and len(train_df) > MAX_TRAIN_SAMPLES:
        print(f"train_super имеет {len(train_df)} строк, "
              f"режем до {MAX_TRAIN_SAMPLES} для обучения...")
        train_df = train_df.sample(
            n=MAX_TRAIN_SAMPLES,
            random_state=RANDOM_STATE
        ).reset_index(drop=True)

    print("Размер train:", train_df.shape)
    print("Размер val:  ", val_df.shape)
    print("\nРаспределение классов (train):")
    print(train_df["label"].value_counts().sort_index())
    print("\nРаспределение классов (val):")
    print(val_df["label"].value_counts().sort_index())

    # Выбор устройства
    if torch.backends.mps.is_available():
        device = torch.device("mps")     # Mac M1/M2/M3/M4
    elif torch.cuda.is_available():
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")
    print("\nИспользуем устройство:", device)

    print("\nЗагружаем токенизатор и модель:", MODEL_ID)
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
    model = AutoModelForSequenceClassification.from_pretrained(
        MODEL_ID,
        num_labels=NUM_LABELS,
    )
    model.to(device)

    # Datasets / Dataloaders
    train_dataset = TextDataset(
        texts=train_df["text"].tolist(),
        labels=train_df["label"].tolist(),
        tokenizer=tokenizer,
        max_len=MAX_LEN,
    )
    val_dataset = TextDataset(
        texts=val_df["text"].tolist(),
        labels=val_df["label"].tolist(),
        tokenizer=tokenizer,
        max_len=MAX_LEN,
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=0,   # на Mac — без multiprocessing
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=0,
    )

    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)

    # считаем шаги оптимизатора (с учётом grad_accum)
    num_update_steps_per_epoch = math.ceil(len(train_loader) / GRAD_ACCUM_STEPS)
    total_optim_steps = num_update_steps_per_epoch * EPOCHS
    num_warmup_steps = int(WARMUP_RATIO * total_optim_steps)

    print(f"\nВсего optimizer steps: {total_optim_steps}, "
          f"warmup steps: {num_warmup_steps}")

    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=num_warmup_steps,
        num_training_steps=total_optim_steps,
    )

    best_f1 = -1.0
    history = []
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    for epoch in range(1, EPOCHS + 1):
        print(f"\n===== Эпоха {epoch}/{EPOCHS} =====")
        start_time = time.time()

        train_loss, train_acc, train_f1 = train_one_epoch(
            model,
            train_loader,
            optimizer,
            scheduler,
            device,
            grad_accum_steps=GRAD_ACCUM_STEPS,
            epoch_idx=epoch,
        )
        val_loss, val_acc, val_f1 = eval_one_epoch(
            model,
            val_loader,
            device,
            epoch_idx=epoch,
        )

        elapsed = time.time() - start_time
        current_lr = scheduler.get_last_lr()[0]

        print(
            f"\nTrain | loss: {train_loss:.4f} | acc: {train_acc:.4f} | f1_macro: {train_f1:.4f}"
        )
        print(
            f"Val   | loss: {val_loss:.4f} | acc: {val_acc:.4f} | f1_macro: {val_f1:.4f}"
        )
        print(f"LR: {current_lr:.6f}")
        print(f"Время эпохи: {elapsed/60:.2f} мин")

        history.append(
            {
                "epoch": epoch,
                "train_loss": train_loss,
                "train_acc": train_acc,
                "train_f1": train_f1,
                "val_loss": val_loss,
                "val_acc": val_acc,
                "val_f1": val_f1,
                "lr": current_lr,
                "time_min": elapsed / 60,
            }
        )

        if val_f1 > best_f1:
            best_f1 = val_f1
            print(f"🔥 Новый лучший F1: {best_f1:.4f}, сохраняем модель...")
            model.save_pretrained(OUTPUT_DIR)
            tokenizer.save_pretrained(OUTPUT_DIR)

    hist_df = pd.DataFrame(history)
    hist_df.to_csv(
        os.path.join(OUTPUT_DIR, "training_history_rurorberta_tiny.csv"),
        index=False
    )

    print("\nОбучение завершено.")
    print(f"Лучшая macro-F1 на валидации: {best_f1:.4f}")
    print("Модель сохранена в:", OUTPUT_DIR)
    print("История обучения сохранена в:",
          os.path.join(OUTPUT_DIR, "training_history_rurorberta_tiny.csv"))


if __name__ == "__main__":
    main()
# Out:
# Читаем данные...
# Размер train: (106311, 4)
# Размер val:   (11771, 4)
#
# Распределение классов (train):
# label
# 0    35437
# 1    35437
# 2    35437
# Name: count, dtype: int64
#
# Распределение классов (val):
# label
# 0    3896
# 1    3937
# 2    3938
# Name: count, dtype: int64
#
# Используем устройство: mps
#
# Загружаем токенизатор и модель: cointegrated/rubert-tiny2
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Всего optimizer steps: 6646, warmup steps: 398
#
# ===== Эпоха 1/2 =====
# [Train] Epoch 1 | batch 200/13289 (1.5%) | avg_loss: 1.1015 | lr: 0.000003 | elapsed: 0.2 мин
# [Train] Epoch 1 | batch 400/13289 (3.0%) | avg_loss: 1.1001 | lr: 0.000005 | elapsed: 0.3 мин
# [Train] Epoch 1 | batch 600/13289 (4.5%) | avg_loss: 1.0980 | lr: 0.000008 | elapsed: 0.4 мин
# [Train] Epoch 1 | batch 800/13289 (6.0%) | avg_loss: 1.0941 | lr: 0.000010 | elapsed: 0.5 мин
# [Train] Epoch 1 | batch 1000/13289 (7.5%) | avg_loss: 1.0863 | lr: 0.000013 | elapsed: 0.6 мин
# [Train] Epoch 1 | batch 1200/13289 (9.0%) | avg_loss: 1.0730 | lr: 0.000015 | elapsed: 0.8 мин
# [Train] Epoch 1 | batch 1400/13289 (10.5%) | avg_loss: 1.0548 | lr: 0.000018 | elapsed: 0.9 мин
# [Train] Epoch 1 | batch 1600/13289 (12.0%) | avg_loss: 1.0344 | lr: 0.000020 | elapsed: 1.0 мин
# [Train] Epoch 1 | batch 1800/13289 (13.5%) | avg_loss: 1.0156 | lr: 0.000020 | elapsed: 1.1 мин
# [Train] Epoch 1 | batch 2000/13289 (15.1%) | avg_loss: 1.0008 | lr: 0.000020 | elapsed: 1.2 мин
# [Train] Epoch 1 | batch 2200/13289 (16.6%) | avg_loss: 0.9880 | lr: 0.000020 | elapsed: 1.4 мин
# [Train] Epoch 1 | batch 2400/13289 (18.1%) | avg_loss: 0.9766 | lr: 0.000019 | elapsed: 1.5 мин
# [Train] Epoch 1 | batch 2600/13289 (19.6%) | avg_loss: 0.9658 | lr: 0.000019 | elapsed: 1.6 мин
# [Train] Epoch 1 | batch 2800/13289 (21.1%) | avg_loss: 0.9559 | lr: 0.000019 | elapsed: 1.7 мин
# [Train] Epoch 1 | batch 3000/13289 (22.6%) | avg_loss: 0.9456 | lr: 0.000019 | elapsed: 1.9 мин
# [Train] Epoch 1 | batch 3200/13289 (24.1%) | avg_loss: 0.9353 | lr: 0.000019 | elapsed: 2.0 мин
# [Train] Epoch 1 | batch 3400/13289 (25.6%) | avg_loss: 0.9272 | lr: 0.000019 | elapsed: 2.1 мин
# [Train] Epoch 1 | batch 3600/13289 (27.1%) | avg_loss: 0.9201 | lr: 0.000018 | elapsed: 2.2 мин
# [Train] Epoch 1 | batch 3800/13289 (28.6%) | avg_loss: 0.9137 | lr: 0.000018 | elapsed: 2.3 мин
# [Train] Epoch 1 | batch 4000/13289 (30.1%) | avg_loss: 0.9074 | lr: 0.000018 | elapsed: 2.5 мин
# [Train] Epoch 1 | batch 4200/13289 (31.6%) | avg_loss: 0.9013 | lr: 0.000018 | elapsed: 2.6 мин
# [Train] Epoch 1 | batch 4400/13289 (33.1%) | avg_loss: 0.8959 | lr: 0.000018 | elapsed: 2.7 мин
# [Train] Epoch 1 | batch 4600/13289 (34.6%) | avg_loss: 0.8906 | lr: 0.000018 | elapsed: 2.8 мин
# [Train] Epoch 1 | batch 4800/13289 (36.1%) | avg_loss: 0.8865 | lr: 0.000017 | elapsed: 2.9 мин
# [Train] Epoch 1 | batch 5000/13289 (37.6%) | avg_loss: 0.8821 | lr: 0.000017 | elapsed: 3.1 мин
# [Train] Epoch 1 | batch 5200/13289 (39.1%) | avg_loss: 0.8780 | lr: 0.000017 | elapsed: 3.2 мин
# [Train] Epoch 1 | batch 5400/13289 (40.6%) | avg_loss: 0.8736 | lr: 0.000017 | elapsed: 3.3 мин
# [Train] Epoch 1 | batch 5600/13289 (42.1%) | avg_loss: 0.8693 | lr: 0.000017 | elapsed: 3.4 мин
# [Train] Epoch 1 | batch 5800/13289 (43.6%) | avg_loss: 0.8658 | lr: 0.000017 | elapsed: 3.5 мин
# [Train] Epoch 1 | batch 6000/13289 (45.2%) | avg_loss: 0.8625 | lr: 0.000016 | elapsed: 3.7 мин
# [Train] Epoch 1 | batch 6200/13289 (46.7%) | avg_loss: 0.8592 | lr: 0.000016 | elapsed: 3.8 мин
# [Train] Epoch 1 | batch 6400/13289 (48.2%) | avg_loss: 0.8557 | lr: 0.000016 | elapsed: 3.9 мин
# [Train] Epoch 1 | batch 6600/13289 (49.7%) | avg_loss: 0.8523 | lr: 0.000016 | elapsed: 4.0 мин
# [Train] Epoch 1 | batch 6800/13289 (51.2%) | avg_loss: 0.8490 | lr: 0.000016 | elapsed: 4.2 мин
# [Train] Epoch 1 | batch 7000/13289 (52.7%) | avg_loss: 0.8454 | lr: 0.000016 | elapsed: 4.3 мин
# [Train] Epoch 1 | batch 7200/13289 (54.2%) | avg_loss: 0.8425 | lr: 0.000016 | elapsed: 4.4 мин
# [Train] Epoch 1 | batch 7400/13289 (55.7%) | avg_loss: 0.8406 | lr: 0.000015 | elapsed: 4.5 мин
# [Train] Epoch 1 | batch 7600/13289 (57.2%) | avg_loss: 0.8382 | lr: 0.000015 | elapsed: 4.6 мин
# [Train] Epoch 1 | batch 7800/13289 (58.7%) | avg_loss: 0.8352 | lr: 0.000015 | elapsed: 4.8 мин
# [Train] Epoch 1 | batch 8000/13289 (60.2%) | avg_loss: 0.8328 | lr: 0.000015 | elapsed: 4.9 мин
# [Train] Epoch 1 | batch 8200/13289 (61.7%) | avg_loss: 0.8301 | lr: 0.000015 | elapsed: 5.0 мин
# [Train] Epoch 1 | batch 8400/13289 (63.2%) | avg_loss: 0.8277 | lr: 0.000015 | elapsed: 5.1 мин
# [Train] Epoch 1 | batch 8600/13289 (64.7%) | avg_loss: 0.8264 | lr: 0.000014 | elapsed: 5.2 мин
# [Train] Epoch 1 | batch 8800/13289 (66.2%) | avg_loss: 0.8238 | lr: 0.000014 | elapsed: 5.4 мин
# [Train] Epoch 1 | batch 9000/13289 (67.7%) | avg_loss: 0.8215 | lr: 0.000014 | elapsed: 5.5 мин
# [Train] Epoch 1 | batch 9200/13289 (69.2%) | avg_loss: 0.8202 | lr: 0.000014 | elapsed: 5.6 мин
# [Train] Epoch 1 | batch 9400/13289 (70.7%) | avg_loss: 0.8182 | lr: 0.000014 | elapsed: 5.7 мин
# [Train] Epoch 1 | batch 9600/13289 (72.2%) | avg_loss: 0.8160 | lr: 0.000014 | elapsed: 5.8 мин
# [Train] Epoch 1 | batch 9800/13289 (73.7%) | avg_loss: 0.8145 | lr: 0.000013 | elapsed: 6.0 мин
# [Train] Epoch 1 | batch 10000/13289 (75.3%) | avg_loss: 0.8122 | lr: 0.000013 | elapsed: 6.1 мин
# [Train] Epoch 1 | batch 10200/13289 (76.8%) | avg_loss: 0.8101 | lr: 0.000013 | elapsed: 6.2 мин
# [Train] Epoch 1 | batch 10400/13289 (78.3%) | avg_loss: 0.8088 | lr: 0.000013 | elapsed: 6.3 мин
# [Train] Epoch 1 | batch 10600/13289 (79.8%) | avg_loss: 0.8072 | lr: 0.000013 | elapsed: 6.5 мин
# [Train] Epoch 1 | batch 10800/13289 (81.3%) | avg_loss: 0.8057 | lr: 0.000013 | elapsed: 6.6 мин
# [Train] Epoch 1 | batch 11000/13289 (82.8%) | avg_loss: 0.8042 | lr: 0.000012 | elapsed: 6.7 мин
# [Train] Epoch 1 | batch 11200/13289 (84.3%) | avg_loss: 0.8024 | lr: 0.000012 | elapsed: 6.8 мин
# [Train] Epoch 1 | batch 11400/13289 (85.8%) | avg_loss: 0.8010 | lr: 0.000012 | elapsed: 6.9 мин
# [Train] Epoch 1 | batch 11600/13289 (87.3%) | avg_loss: 0.7997 | lr: 0.000012 | elapsed: 7.1 мин
# [Train] Epoch 1 | batch 11800/13289 (88.8%) | avg_loss: 0.7977 | lr: 0.000012 | elapsed: 7.2 мин
# [Train] Epoch 1 | batch 12000/13289 (90.3%) | avg_loss: 0.7962 | lr: 0.000012 | elapsed: 7.3 мин
# [Train] Epoch 1 | batch 12200/13289 (91.8%) | avg_loss: 0.7949 | lr: 0.000012 | elapsed: 7.4 мин
# [Train] Epoch 1 | batch 12400/13289 (93.3%) | avg_loss: 0.7938 | lr: 0.000011 | elapsed: 7.5 мин
# [Train] Epoch 1 | batch 12600/13289 (94.8%) | avg_loss: 0.7925 | lr: 0.000011 | elapsed: 7.7 мин
# [Train] Epoch 1 | batch 12800/13289 (96.3%) | avg_loss: 0.7912 | lr: 0.000011 | elapsed: 7.8 мин
# [Train] Epoch 1 | batch 13000/13289 (97.8%) | avg_loss: 0.7900 | lr: 0.000011 | elapsed: 7.9 мин
# [Train] Epoch 1 | batch 13200/13289 (99.3%) | avg_loss: 0.7886 | lr: 0.000011 | elapsed: 8.0 мин
# [Train] Epoch 1 | batch 13289/13289 (100.0%) | avg_loss: 0.7880 | lr: 0.000011 | elapsed: 8.1 мин
# [Val] Epoch 1 | batch 200/1472 (13.6%) | avg_loss: 0.7013 | elapsed: 0.0 мин
# [Val] Epoch 1 | batch 400/1472 (27.2%) | avg_loss: 0.6983 | elapsed: 0.1 мин
# [Val] Epoch 1 | batch 600/1472 (40.8%) | avg_loss: 0.7059 | elapsed: 0.1 мин
# [Val] Epoch 1 | batch 800/1472 (54.3%) | avg_loss: 0.7024 | elapsed: 0.2 мин
# [Val] Epoch 1 | batch 1000/1472 (67.9%) | avg_loss: 0.7028 | elapsed: 0.2 мин
# [Val] Epoch 1 | batch 1200/1472 (81.5%) | avg_loss: 0.6989 | elapsed: 0.2 мин
# [Val] Epoch 1 | batch 1400/1472 (95.1%) | avg_loss: 0.7001 | elapsed: 0.3 мин
# [Val] Epoch 1 | batch 1472/1472 (100.0%) | avg_loss: 0.6998 | elapsed: 0.3 мин
#
# Train | loss: 0.7880 | acc: 0.6239 | f1_macro: 0.6218
# Val   | loss: 0.6998 | acc: 0.6692 | f1_macro: 0.6661
# LR: 0.000011
# Время эпохи: 8.38 мин
# 🔥 Новый лучший F1: 0.6661, сохраняем модель...
#
# ===== Эпоха 2/2 =====
# [Train] Epoch 2 | batch 200/13289 (1.5%) | avg_loss: 0.6763 | lr: 0.000010 | elapsed: 0.1 мин
# [Train] Epoch 2 | batch 400/13289 (3.0%) | avg_loss: 0.6706 | lr: 0.000010 | elapsed: 0.2 мин
# [Train] Epoch 2 | batch 600/13289 (4.5%) | avg_loss: 0.6729 | lr: 0.000010 | elapsed: 0.4 мин
# [Train] Epoch 2 | batch 800/13289 (6.0%) | avg_loss: 0.6774 | lr: 0.000010 | elapsed: 0.5 мин
# [Train] Epoch 2 | batch 1000/13289 (7.5%) | avg_loss: 0.6751 | lr: 0.000010 | elapsed: 0.6 мин
# [Train] Epoch 2 | batch 1200/13289 (9.0%) | avg_loss: 0.6771 | lr: 0.000010 | elapsed: 0.7 мин
# [Train] Epoch 2 | batch 1400/13289 (10.5%) | avg_loss: 0.6784 | lr: 0.000010 | elapsed: 0.8 мин
# [Train] Epoch 2 | batch 1600/13289 (12.0%) | avg_loss: 0.6779 | lr: 0.000009 | elapsed: 1.0 мин
# [Train] Epoch 2 | batch 1800/13289 (13.5%) | avg_loss: 0.6792 | lr: 0.000009 | elapsed: 1.1 мин
# [Train] Epoch 2 | batch 2000/13289 (15.1%) | avg_loss: 0.6788 | lr: 0.000009 | elapsed: 1.2 мин
# [Train] Epoch 2 | batch 2200/13289 (16.6%) | avg_loss: 0.6795 | lr: 0.000009 | elapsed: 1.3 мин
# [Train] Epoch 2 | batch 2400/13289 (18.1%) | avg_loss: 0.6785 | lr: 0.000009 | elapsed: 1.4 мин
# [Train] Epoch 2 | batch 2600/13289 (19.6%) | avg_loss: 0.6790 | lr: 0.000009 | elapsed: 1.6 мин
# [Train] Epoch 2 | batch 2800/13289 (21.1%) | avg_loss: 0.6791 | lr: 0.000008 | elapsed: 1.7 мин
# [Train] Epoch 2 | batch 3000/13289 (22.6%) | avg_loss: 0.6805 | lr: 0.000008 | elapsed: 1.8 мин
# [Train] Epoch 2 | batch 3200/13289 (24.1%) | avg_loss: 0.6778 | lr: 0.000008 | elapsed: 1.9 мин
# [Train] Epoch 2 | batch 3400/13289 (25.6%) | avg_loss: 0.6766 | lr: 0.000008 | elapsed: 2.0 мин
# [Train] Epoch 2 | batch 3600/13289 (27.1%) | avg_loss: 0.6765 | lr: 0.000008 | elapsed: 2.2 мин
# [Train] Epoch 2 | batch 3800/13289 (28.6%) | avg_loss: 0.6769 | lr: 0.000008 | elapsed: 2.3 мин
# [Train] Epoch 2 | batch 4000/13289 (30.1%) | avg_loss: 0.6753 | lr: 0.000007 | elapsed: 2.4 мин
# [Train] Epoch 2 | batch 4200/13289 (31.6%) | avg_loss: 0.6754 | lr: 0.000007 | elapsed: 2.5 мин
# [Train] Epoch 2 | batch 4400/13289 (33.1%) | avg_loss: 0.6759 | lr: 0.000007 | elapsed: 2.6 мин
# [Train] Epoch 2 | batch 4600/13289 (34.6%) | avg_loss: 0.6761 | lr: 0.000007 | elapsed: 2.8 мин
# [Train] Epoch 2 | batch 4800/13289 (36.1%) | avg_loss: 0.6774 | lr: 0.000007 | elapsed: 2.9 мин
# [Train] Epoch 2 | batch 5000/13289 (37.6%) | avg_loss: 0.6775 | lr: 0.000007 | elapsed: 3.0 мин
# [Train] Epoch 2 | batch 5200/13289 (39.1%) | avg_loss: 0.6783 | lr: 0.000006 | elapsed: 3.1 мин
# [Train] Epoch 2 | batch 5400/13289 (40.6%) | avg_loss: 0.6779 | lr: 0.000006 | elapsed: 3.3 мин
# [Train] Epoch 2 | batch 5600/13289 (42.1%) | avg_loss: 0.6771 | lr: 0.000006 | elapsed: 3.4 мин
# [Train] Epoch 2 | batch 5800/13289 (43.6%) | avg_loss: 0.6763 | lr: 0.000006 | elapsed: 3.5 мин
# [Train] Epoch 2 | batch 6000/13289 (45.2%) | avg_loss: 0.6760 | lr: 0.000006 | elapsed: 3.6 мин
# [Train] Epoch 2 | batch 6200/13289 (46.7%) | avg_loss: 0.6759 | lr: 0.000006 | elapsed: 3.7 мин
# [Train] Epoch 2 | batch 6400/13289 (48.2%) | avg_loss: 0.6756 | lr: 0.000006 | elapsed: 3.9 мин
# [Train] Epoch 2 | batch 6600/13289 (49.7%) | avg_loss: 0.6753 | lr: 0.000005 | elapsed: 4.0 мин
# [Train] Epoch 2 | batch 6800/13289 (51.2%) | avg_loss: 0.6754 | lr: 0.000005 | elapsed: 4.1 мин
# [Train] Epoch 2 | batch 7000/13289 (52.7%) | avg_loss: 0.6753 | lr: 0.000005 | elapsed: 4.2 мин
# [Train] Epoch 2 | batch 7200/13289 (54.2%) | avg_loss: 0.6749 | lr: 0.000005 | elapsed: 4.4 мин
# [Train] Epoch 2 | batch 7400/13289 (55.7%) | avg_loss: 0.6746 | lr: 0.000005 | elapsed: 4.5 мин
# [Train] Epoch 2 | batch 7600/13289 (57.2%) | avg_loss: 0.6747 | lr: 0.000005 | elapsed: 4.6 мин
# [Train] Epoch 2 | batch 7800/13289 (58.7%) | avg_loss: 0.6744 | lr: 0.000004 | elapsed: 4.7 мин
# [Train] Epoch 2 | batch 8000/13289 (60.2%) | avg_loss: 0.6739 | lr: 0.000004 | elapsed: 4.8 мин
# [Train] Epoch 2 | batch 8200/13289 (61.7%) | avg_loss: 0.6742 | lr: 0.000004 | elapsed: 5.0 мин
# [Train] Epoch 2 | batch 8400/13289 (63.2%) | avg_loss: 0.6744 | lr: 0.000004 | elapsed: 5.1 мин
# [Train] Epoch 2 | batch 8600/13289 (64.7%) | avg_loss: 0.6737 | lr: 0.000004 | elapsed: 5.2 мин
# [Train] Epoch 2 | batch 8800/13289 (66.2%) | avg_loss: 0.6733 | lr: 0.000004 | elapsed: 5.3 мин
# [Train] Epoch 2 | batch 9000/13289 (67.7%) | avg_loss: 0.6728 | lr: 0.000003 | elapsed: 5.4 мин
# [Train] Epoch 2 | batch 9200/13289 (69.2%) | avg_loss: 0.6727 | lr: 0.000003 | elapsed: 5.6 мин
# [Train] Epoch 2 | batch 9400/13289 (70.7%) | avg_loss: 0.6726 | lr: 0.000003 | elapsed: 5.7 мин
# [Train] Epoch 2 | batch 9600/13289 (72.2%) | avg_loss: 0.6724 | lr: 0.000003 | elapsed: 5.8 мин
# [Train] Epoch 2 | batch 9800/13289 (73.7%) | avg_loss: 0.6719 | lr: 0.000003 | elapsed: 5.9 мин
# [Train] Epoch 2 | batch 10000/13289 (75.3%) | avg_loss: 0.6720 | lr: 0.000003 | elapsed: 6.1 мин
# [Train] Epoch 2 | batch 10200/13289 (76.8%) | avg_loss: 0.6719 | lr: 0.000002 | elapsed: 6.2 мин
# [Train] Epoch 2 | batch 10400/13289 (78.3%) | avg_loss: 0.6722 | lr: 0.000002 | elapsed: 6.3 мин
# [Train] Epoch 2 | batch 10600/13289 (79.8%) | avg_loss: 0.6720 | lr: 0.000002 | elapsed: 6.4 мин
# [Train] Epoch 2 | batch 10800/13289 (81.3%) | avg_loss: 0.6717 | lr: 0.000002 | elapsed: 6.6 мин
# [Train] Epoch 2 | batch 11000/13289 (82.8%) | avg_loss: 0.6718 | lr: 0.000002 | elapsed: 6.7 мин
# [Train] Epoch 2 | batch 11200/13289 (84.3%) | avg_loss: 0.6714 | lr: 0.000002 | elapsed: 6.8 мин
# [Train] Epoch 2 | batch 11400/13289 (85.8%) | avg_loss: 0.6711 | lr: 0.000002 | elapsed: 6.9 мин
# [Train] Epoch 2 | batch 11600/13289 (87.3%) | avg_loss: 0.6709 | lr: 0.000001 | elapsed: 7.0 мин
# [Train] Epoch 2 | batch 11800/13289 (88.8%) | avg_loss: 0.6710 | lr: 0.000001 | elapsed: 7.2 мин
# [Train] Epoch 2 | batch 12000/13289 (90.3%) | avg_loss: 0.6708 | lr: 0.000001 | elapsed: 7.3 мин
# [Train] Epoch 2 | batch 12200/13289 (91.8%) | avg_loss: 0.6711 | lr: 0.000001 | elapsed: 7.4 мин
# [Train] Epoch 2 | batch 12400/13289 (93.3%) | avg_loss: 0.6711 | lr: 0.000001 | elapsed: 7.5 мин
# [Train] Epoch 2 | batch 12600/13289 (94.8%) | avg_loss: 0.6710 | lr: 0.000001 | elapsed: 7.7 мин
# [Train] Epoch 2 | batch 12800/13289 (96.3%) | avg_loss: 0.6708 | lr: 0.000000 | elapsed: 7.8 мин
# [Train] Epoch 2 | batch 13000/13289 (97.8%) | avg_loss: 0.6703 | lr: 0.000000 | elapsed: 7.9 мин
# [Train] Epoch 2 | batch 13200/13289 (99.3%) | avg_loss: 0.6701 | lr: 0.000000 | elapsed: 8.0 мин
# [Train] Epoch 2 | batch 13289/13289 (100.0%) | avg_loss: 0.6703 | lr: 0.000000 | elapsed: 8.1 мин
# [Val] Epoch 2 | batch 200/1472 (13.6%) | avg_loss: 0.6781 | elapsed: 0.0 мин
# [Val] Epoch 2 | batch 400/1472 (27.2%) | avg_loss: 0.6801 | elapsed: 0.1 мин
# [Val] Epoch 2 | batch 600/1472 (40.8%) | avg_loss: 0.6859 | elapsed: 0.1 мин
# [Val] Epoch 2 | batch 800/1472 (54.3%) | avg_loss: 0.6825 | elapsed: 0.2 мин
# [Val] Epoch 2 | batch 1000/1472 (67.9%) | avg_loss: 0.6833 | elapsed: 0.2 мин
# [Val] Epoch 2 | batch 1200/1472 (81.5%) | avg_loss: 0.6788 | elapsed: 0.2 мин
# [Val] Epoch 2 | batch 1400/1472 (95.1%) | avg_loss: 0.6804 | elapsed: 0.3 мин
# [Val] Epoch 2 | batch 1472/1472 (100.0%) | avg_loss: 0.6799 | elapsed: 0.3 мин
#
# Train | loss: 0.6703 | acc: 0.6942 | f1_macro: 0.6941
# Val   | loss: 0.6799 | acc: 0.6885 | f1_macro: 0.6871
# LR: 0.000000
# Время эпохи: 8.36 мин
# 🔥 Новый лучший F1: 0.6871, сохраняем модель...
#
# Обучение завершено.
# Лучшая macro-F1 на валидации: 0.6871
# Модель сохранена в: ../models/rurorberta_base_manual
# История обучения сохранена в: ../models/rurorberta_base_manual/training_history_rurorberta_base.csv
